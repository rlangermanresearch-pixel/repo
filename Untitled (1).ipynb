# %%
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy

# %%
import tensorflow

# %%
conda info --envs
# Out:
# # conda environments:
# #
# # * -> active
# # + -> frozen
# base                     /opt/anaconda3
# Dogbowl              *   /opt/anaconda3/envs/Dogbowl
# dogbowl                  /opt/anaconda3/envs/dogbowl
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda activate Dogbowl
# Out:
# CondaError: Run 'conda init' before 'conda activate'
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda init
# Out:
# no change     /opt/anaconda3/condabin/conda
# no change     /opt/anaconda3/bin/conda
# no change     /opt/anaconda3/bin/conda-env
# no change     /opt/anaconda3/bin/activate
# no change     /opt/anaconda3/bin/deactivate
# no change     /opt/anaconda3/etc/profile.d/conda.sh
# no change     /opt/anaconda3/etc/fish/conf.d/conda.fish
# no change     /opt/anaconda3/shell/condabin/Conda.psm1
# no change     /opt/anaconda3/shell/condabin/conda-hook.ps1
# no change     /opt/anaconda3/lib/python3.13/site-packages/xontrib/conda.xsh
# no change     /opt/anaconda3/etc/profile.d/conda.csh
# no change     /Users/ryanlangerman/.bash_profile
# No action taken.
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda init conda activate Dogbowl
# Out:
# usage: conda init [-h] [--all] [--condabin] [--user] [--no-user] [--system]
#                   [--reverse] [--json] [--console CONSOLE] [-v] [-q] [-d]
#                   [SHELLS ...]
# conda init: error: argument SHELLS: invalid choice: 'conda' (choose from bash, fish, tcsh, xonsh, zsh, powershell)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
a = 5
b = 2
sum = a + b

# %%
print(sum)
